# %% [markdown]
# <a href="https://colab.research.google.com/github/uzh-rpg/rpg_timelens/blob/main/TimeLens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TimeLens: Event-based Video Frame Interpolation

# %% [markdown]
# ## Installation
#
# First clone the repo and install an environment

# %%
# Check your current GPU
# If you are lucky, you get 16GB VRAM. If you are not lucky, you get less. VRAM is important. The more VRAM, the higher the maximum resolution will go
# !nvidia-smi
# Out:
# Fri Sep 22 07:10:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Connect Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
print('Google Drive connected.')
# Out:
# Mounted at /content/gdrive
# Google Drive connected.

# %%
# !ls /content/gdrive
# Out:
# MyDrive

# %%
# %%bash
# rm -rf /content/rpg_timelens
# rm -rf /content/ontent
# rm -rf /content/sample_data
# rm -rf /content/example

# %% [markdown]
# # Install Dependencies and Repo

# %%
# %cd /content
# !git clone https://github.com/uzh-rpg/rpg_timelens
# !git clone https://github.com/Chohoonhee/rpg_timelens
# !git clone https://github.com/AI-Expert-Project/rpg_timelens
# %cd /content/rpg_timelens
# !wget http://rpg.ifi.uzh.ch/timelens/data2/checkpoint.bin
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1O43qlJMvmKQLMKlXlp42V7_Ww1r7sWio' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1O43qlJMvmKQLMKlXlp42V7_Ww1r7sWio" -O checkpoint.bin && rm -rf ~/cookies.txt

# !CUDA_VISIBLE_DEVICES=0
# Out:
# /content
# Cloning into 'rpg_timelens'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 146 (delta 28), reused 16 (delta 16), pack-reused 103
# Receiving objects: 100% (146/146), 73.59 MiB | 1.25 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# /content/rpg_timelens
# --2023-09-22 07:15:39--  https://docs.google.com/uc?export=download&confirm=t&id=1O43qlJMvmKQLMKlXlp42V7_Ww1r7sWio
# Resolving docs.google.com (docs.google.com)... 142.251.12.138, 142.251.12.113, 142.251.12.139, ...
# Connecting to docs.google.com (docs.google.com)|142.251.12.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-a8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ff1jje20mk455oje0nvoqo8gfbch1itm/1695366900000/18100762325334682086/*/1O43qlJMvmKQLMKlXlp42V7_Ww1r7sWio?e=download&uuid=113724f8-7024-4bd1-bed6-a16d8316c299 [following]
# Warning: wildcards not supported in HTTP.
# --2023-09-22 07:15:39--  https://doc-00-a8-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ff1jje20mk455oje0nvoqo8gfbch1itm/1695366900000/18100762325334682086/*/1O43qlJMvmKQLMKlXlp42V7_Ww1r7sWio?e=download&uuid=113724f8-7024-4bd1-bed6-a16d8316c299
# Resolving doc-00-a8-docs.googleusercontent.com (doc-00-a8-docs.googleusercontent.com)... 74.125.200.132, 2404:6800:4003:c00::84
# Connecting to doc-00-a8-docs.googleusercontent.com (doc-00-a8-docs.googleusercontent.com)|74.125.200.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 475379363 (453M) [application/x-zip]
# Saving to: ‘checkpoint.bin’
#
# checkpoint.bin      100%[===================>] 453.36M  60.9MB/s    in 6.9s
#
# 2023-09-22 07:15:47 (65.9 MB/s) - ‘checkpoint.bin’ saved [475379363/475379363]

# %%
################# Required Configurations ############################

#@markdown # Required Configuration
#@markdown Use the values in here to configure what you'd like TimeLens to do. If you do not have your own data, just leave the values below and it will download an example.

#@markdown ## Output file
#@markdown Output file path: path (relative to the root of your Google Drive) for the output file. It will also determine the filetype in the destination. `.mp4` is recommended for video input, `.gif` for gif inputs.
OUTPUT_FILE_PATH = "/content/rpg_timelens/out.mp4" #@param{type:"string"}

################# Optional configurations ############################

#@markdown # Optional Configuration
#@markdown Parameters below can be left with their defaults, but feel free to adapt them to your needs.

#@markdown ## Target FPS
#@markdown  how many frames per second should the result have. This will determine how many intermediate images are interpolated.
TARGET_FPS =  960#@param{type:"number"}

#@markdown ## Frame input directory
#@markdown A path, relative to your GDrive root, where you already have the list of frames in the format 00001.png, 00002.png, etc.
FRAME_INPUT_DIR = '/content/rpg_timelens/input_frames' #@param{type:"string"}
EVENTS_INPUT_DIR = '/content/rpg_timelens/input_events' #@param{type:"string"}

#@markdown ## Frame output directory
#@markdown A path, relative to your GDrive root, where you want the generated frame.
FRAME_OUTPUT_DIR = '/content/rpg_timelens/output_frames' #@param{type:"string"}

# %% [markdown]
# # Set Up Example
# If you do not have data to process, just leave the default values in the form above and the cell below will download an example.

# %%
# Example

# %%bash
wget http://rpg.ifi.uzh.ch/timelens/data2/example_github.zip -O /content/example_github.zip
unzip /content/example_github.zip -d /content/
rm -rf /content/example_github.zip
mv /content/example/events /content/rpg_timelens/input_events
mv /content/example/images /content/rpg_timelens/input_frames
mkdir /content/rpg_timelens/output_frames
# Out:
# Archive:  /content/example_github.zip
#    creating: /content/example/
#    creating: /content/example/events/
#   inflating: /content/example/events/000358.npz
#   inflating: /content/example/events/000371.npz
#   inflating: /content/example/events/000368.npz
#   inflating: /content/example/events/000376.npz
#   inflating: /content/example/events/000383.npz
#   inflating: /content/example/events/000351.npz
#   inflating: /content/example/events/000353.npz
#   inflating: /content/example/events/000382.npz
#   inflating: /content/example/events/000365.npz
#   inflating: /content/example/events/000391.npz
#   inflating: /content/example/events/000354.npz
#   inflating: /content/example/events/000352.npz
#   inflating: /content/example/events/000356.npz
#   inflating: /content/example/events/000398.npz
#   inflating: /content/example/events/000389.npz
#   inflating: /content/example/events/000367.npz
#   inflating: /content/example/events/000381.npz
#   inflating: /content/example/events/000360.npz
#   inflating: /content/example/events/000399.npz
#   inflating: /content/example/events/000350.npz
#   inflating: /content/example/events/000361.npz
#   inflating: /content/example/events/000364.npz
#   inflating: /content/example/events/000394.npz
#   inflating: /content/example/events/000387.npz
#   inflating: /content/example/events/000375.npz
#   inflating: /content/example/events/000370.npz
#   inflating: /content/example/events/000373.npz
#   inflating: /content/example/events/000388.npz
#   inflating: /content/example/events/000369.npz
#   inflating: /content/example/events/000392.npz
#   inflating: /content/example/events/000362.npz
#   inflating: /content/example/events/000378.npz
#   inflating: /content/example/events/000395.npz
#   inflating: /content/example/events/000359.npz
#   inflating: /content/example/events/000363.npz
#   inflating: /content/example/events/000397.npz
#   inflating: /content/example/events/000377.npz
#   inflating: /content/example/events/000374.npz
#   inflating: /content/example/events/000355.npz
#   inflating: /content/example/events/000372.npz
# <img src = "https://drive.google.com/uc?id=1aMlvxCFf8qq7Zz4UNdNJM3wBZCec5bs_" height = 300 width = 1100>

# %%
import os
import sys

import pkg_resources

import torch as th
import torch.nn.functional as F
from timelens.common import size_adapter
from torch import nn

class down(nn.Module):
    def __init__(self, inChannels, outChannels, filterSize):
        super(down, self).__init__()
        self.conv1 = nn.Conv2d(
            inChannels,
            outChannels,
            filterSize,
            stride=1,
            padding=int((filterSize - 1) / 2),
        )
        self.conv2 = nn.Conv2d(
            outChannels,
            outChannels,
            filterSize,
            stride=1,
            padding=int((filterSize - 1) / 2),
        )

    def forward(self, x):
        x = F.avg_pool2d(x, 2)
        x = F.leaky_relu(self.conv1(x), negative_slope=0.1)
        x = F.leaky_relu(self.conv2(x), negative_slope=0.1)
        return x

class up(nn.Module):
    def __init__(self, inChannels, outChannels):
        super(up, self).__init__()
        # self.conv1 = nn.Conv2d(in_channels=?, out_channels=?, kernel_size=? , stride=?, padding=?)
        self.conv1 = nn.Conv2d(in_channels=inChannels, out_channels=outChannels, kernel_size=3, stride=1, padding=1)

        # self.conv2 = nn.Conv2d(in_channels=?, out_channels=outChannels, kernel_size=? , stride=?, padding=?)
        self.conv2 = nn.Conv2d(in_channels=outChannels * 2, out_channels=outChannels, kernel_size=3 , stride=1, padding=1)

    def forward(self, x, skpCn):
        x = F.interpolate(x, scale_factor=2, mode="bilinear")

        x = F.leaky_relu(self.conv1(x), negative_slope=0.1)
        x = F.leaky_relu(self.conv2(th.cat([x, skpCn], dim=1)), negative_slope=0.1) # concatenation
        return x


class UNet(nn.Module):
    """Modified version of Unet from SuperSloMo.

    Difference :
    1) there is an option to skip ReLU after the last convolution.
    2) there is a size adapter module that makes sure that input of all sizes
       can be processed correctly. It is necessary because original
       UNet can process only inputs with spatial dimensions divisible by 32.
    """

    def __init__(self, inChannels, outChannels, ends_with_relu=True):
        super(UNet, self).__init__()
        self._ends_with_relu = ends_with_relu
        self._size_adapter = size_adapter.SizeAdapter(minimum_size=32)
        self.conv1 = nn.Conv2d(inChannels, 32, 7, stride=1, padding=3)
        self.conv2 = nn.Conv2d(32, 32, 7, stride=1, padding=3)
        self.down1 = down(32, 64, 5)
        self.down2 = down(64, 128, 3)
        self.down3 = down(128, 256, 3)
        self.down4 = down(256, 512, 3)
        self.down5 = down(512, 512, 3)
        self.up1 = up(512, 512)
        self.up2 = up(512, 256)
        self.up3 = up(256, 128)
        self.up4 = up(128, 64)
        self.up5 = up(64,32)
        self.conv3 = nn.Conv2d(32, outChannels, 3, stride=1, padding=1)

    def forward(self, x):
        # Size adapter spatially augments input to the size divisible by 32.
        x = self._size_adapter.pad(x)
        x = F.leaky_relu(self.conv1(x), negative_slope=0.1)
        s1 = F.leaky_relu(self.conv2(x), negative_slope=0.1)
        s2 = self.down1(s1)
        s3 = self.down2(s2)
        s4 = self.down3(s3)
        s5 = self.down4(s4)
        x = self.down5(s5)
        x = self.up1(x, s5)
        x = self.up2(x, s4)
        x = self.up3(x, s3)
        x = self.up4(x, s2)
        x = self.up5(x, s1)

        # Note that original code has relu et the end.
        if self._ends_with_relu == True:
            x = F.leaky_relu(self.conv3(x), negative_slope=0.1)
        else:
            x = self.conv3(x)
        # Size adapter crops the output to the original size.
        x = self._size_adapter.unpad(x)
        return x

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=10DOjPpDBfODA4rjjWew5EVyzfoBW58Mx" height = 300 width = 900>

# %%
import torch as th
from timelens.common import warp
from timelens.common import pytorch_tools
from torch import nn


# ----------------------------------Warping-based Interpolation-----------------------------------------------
def _pack_voxel_grid_for_flow_estimation(example):
    return th.cat(
        [example["before"]["reversed_voxel_grid"], example["after"]["voxel_grid"]]
    )

def _pack_images_for_warping(example):
    return th.cat(
        [example["before"]["rgb_image_tensor"], example["after"]["rgb_image_tensor"]]
    )

class Warp(nn.Module):
    def __init__(self):
        super(Warp, self).__init__()
        self.flow_network = UNet(5, 2, False)

    def from_legacy_checkpoint(self, checkpoint_filename):
        checkpoint = th.load(checkpoint_filename)
        self.load_state_dict(checkpoint["networks"])

    def run_warp(self, example):
        flow = self.flow_network(_pack_voxel_grid_for_flow_estimation(example))
        warped, warped_invalid = warp.backwarp_2d(
            source=_pack_images_for_warping(example),
            y_displacement=flow[:, 0, ...],
            x_displacement=flow[:, 1, ...],
        )
        (before_flow, after_flow) = th.chunk(flow, chunks=2)
        (before_warped, after_warped) = th.chunk(warped, chunks=2)
        (before_warped_invalid, after_warped_invalid) = th.chunk(
            warped_invalid.detach(), chunks=2
        )
        return (
            before_warped,
            after_warped,
            before_flow,
            after_flow,
            before_warped_invalid,
            after_warped_invalid,
        )

    def run_and_pack_to_example(self, example):
        _pack_output_to_example(example, self.run_warp(example))

    def forward(self, example):
        return self.run_warp(example)
# ----------------------------------Interpolation Synthesis-----------------------------------------------
def _pack(example):
    return th.cat([example['before']['voxel_grid'],
                   example['before']['rgb_image_tensor'],
                   example['after']['voxel_grid'],
                   example['after']['rgb_image_tensor']], dim=1)

class Fusion(nn.Module):
    def __init__(self):
        super(Fusion, self).__init__()
        self.fusion_network = UNet(2*5 + 2*3, 3, False)

    def run_fusion(self, example):
        return self.fusion_network(_pack(example))

    def from_legacy_checkpoint(self, checkpoint_filename):
        checkpoint = th.load(checkpoint_filename)
        self.load_state_dict(checkpoint["networks"])

    def run_and_pack_to_example(self, example):
        example['middle']['fusion'] = self.run_fusion(example)

    def forward(self, example):
        return self.run_fusion(example)


# ----------------------------------Warping Refinement-----------------------------------------------

def _pack_for_residual_flow_computation(example):
    tensors = [
        example["middle"]["{}_warped".format(packet)] for packet in ["after", "before"]
    ]
    tensors.append(example["middle"]["fusion"])
    return th.cat(tensors, dim=1)


def _pack_images_for_second_warping(example):
    return th.cat(
        [example["middle"]["after_warped"], example["middle"]["before_warped"]],
    )

def _pack_output_to_example(example, output):
    (
        example["middle"]["before_refined_warped"],
        example["middle"]["after_refined_warped"],
        example["middle"]["before_refined_warped_invalid"],
        example["middle"]["after_refined_warped_invalid"],
        example["before"]["residual_flow"],
        example["after"]["residual_flow"],
    ) = output


class RefineWarp(Warp, Fusion):
    def __init__(self):
        Warp.__init__(self)
        self.flow_refinement_network = UNet(3*3 + 2*2, 2, False)

    def run_refine_warp(self, example):
        Warp.run_and_pack_to_example(self, example)
        Fusion.run_and_pack_to_example(self, example)
        residual = self.flow_refinement_network(
            _pack_for_residual_flow_computation(example)
        )
        (after_residual, before_residual) = th.chunk(residual, 2, dim=1)
        residual = th.cat([after_residual, before_residual], dim=0)
        refined, refined_invalid = warp.backwarp_2d(
            source=_pack_images_for_second_warping(example),
            y_displacement=residual[:, 0, ...],
            x_displacement=residual[:, 1, ...],
        )

        (after_refined, before_refined) = th.chunk(refined, 2)
        (after_refined_invalid, before_refined_invalid) = th.chunk(
            refined_invalid.detach(), 2)
        return (
            before_refined,
            after_refined,
            before_refined_invalid,
            after_refined_invalid,
            before_residual,
            after_residual,
        )


    def run_fast(self, example):
        Warp.run_and_pack_to_example(self, example)
        Fusion.run_and_pack_to_example(self, example)
        residual = self.flow_refinement_network(
            _pack_for_residual_flow_computation(example)
        )
        (after_residual, before_residual) = th.chunk(residual, 2, dim=1)
        residual = th.cat([after_residual, before_residual], dim=0)
        refined, _ = warp.backwarp_2d(
            source=_pack_images_for_second_warping(example),
            y_displacement=residual[:, 0, ...],
            x_displacement=residual[:, 1, ...],
        )

        return th.chunk(refined, 2)

    def run_and_pack_to_example(self, example):
        _pack_output_to_example(example, self.run_refine_warp(example))

    def forward(self, example):
        return self.run_refine_warp(example)


# -------------------------------------Attention-based averaging -----------------------------------------
def _pack_input_for_attention_computation(example):
    fusion = example["middle"]["fusion"]
    number_of_examples, _, height, width = fusion.size()
    return th.cat(
        [
            example["after"]["flow"],
            example["middle"]["after_refined_warped"],
            example["before"]["flow"],
            example["middle"]["before_refined_warped"],
            example["middle"]["fusion"],
            th.Tensor(example["middle"]["weight"])
            .view(-1, 1, 1, 1)
            .expand(number_of_examples, 1, height, width)
            .type(fusion.type()),
        ],
        dim=1,
    )


def _compute_weighted_average(attention, before_refined, after_refined, fusion):
    return (
        attention[:, 0, ...].unsqueeze(1) * before_refined
        + attention[:, 1, ...].unsqueeze(1) * after_refined
        + attention[:, 2, ...].unsqueeze(1) * fusion
    )


class AttentionAverage(RefineWarp):
    def __init__(self):
        Warp.__init__(self)
        self.attention_network = UNet(2*2 + 3*2 + 1, 3, False)

    def run_fast(self, example):
        example['middle']['before_refined_warped'],
        example['middle']['after_refined_warped'] = RefineWarp.run_fast(self, example)

        attention_scores = self.attention_network(
            _pack_input_for_attention_computation(example)
        )
        attention = F.softmax(attention_scores, dim=1)
        average = _compute_weighted_average(
            attention,
            example['middle']['before_refined_warped'],
            example['middle']['after_refined_warped'],
            example['middle']['fusion']
        )
        return average, attention

    def run_attention_averaging(self, example):
        RefineWarp.run_and_pack_to_example(self, example)
        attention_scores = self.attention_network(
            _pack_input_for_attention_computation(example)
        )
        attention = F.softmax(attention_scores, dim=1)
        average = _compute_weighted_average(
            attention,
            example["middle"]["before_refined_warped"],
            example["middle"]["after_refined_warped"],
            example["middle"]["fusion"],
        )
        return average, attention

    def run_and_pack_to_example(self, example):
        (
            example["middle"]["attention_average"],
            example["middle"]["attention"],
        ) = self.run_attention_averaging(example)

    def forward(self, example):
        return self.run_attention_averaging(example)

# %% [markdown]
# # Run TimeLens

# %%
# %cd /content/rpg_timelens/
# !mkdir $FRAME_OUTPUT_DIR
# !python -m timelens.run_timelens checkpoint.bin $EVENTS_INPUT_DIR $FRAME_INPUT_DIR $FRAME_OUTPUT_DIR 0 $inserts
# Out:
# /content/rpg_timelens
# mkdir: cannot create directory ‘/content/rpg_timelens/output_frames’: File exists
# Processing .
# 100% 50/50 [00:00<00:00, 167.31it/s]
# Processing /content/rpg_timelens/output_frames/.
# Counter: 0000
# Events left:  6153 Events right:  31367
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Events left:  12482 Events right:  25038
# Events left:  18783 Events right:  18737
# Events left:  25037 Events right:  12483
# Events left:  31292 Events right:  6228
# Counter: 0006
# Events left:  6314 Events right:  30593
# Events left:  12529 Events right:  24378
# Events left:  18630 Events right:  18277
# Events left:  24734 Events right:  12173
# Events left:  30844 Events right:  6063
# Counter: 0012
# Events left:  6036 Events right:  29509
# Events left:  11936 Events right:  23609
# Events left:  17774 Events right:  17771
# Events left:  23759 Events right:  11786
# Events left:  29675 Events right:  5870
# Counter: 0018
# Events left:  6037 Events right:  29217
# Events left:  11927 Events right:  23327
# Events left:  17704 Events right:  17550
# Events left:  23748 Events right:  11506
# Events left:  29619 Events right:  5635
# Counter: 0024
# Events left:  5840 Events right:  28583
# Events left:  11817 Events right:  22606
# Events left:  17390 Events right:  17033
# Events left:  23055 Events right:  11368
# Events left:  28603 Events right:  5820
# Counter: 0030
# Events left:  5614 Events right:  28011
# Events left:  11336 Events right:  22289
# Events left:  16927 Events right:  16698
# Events left:  22649 Events right:  10976
# Events left:  28163 Events right:  5462
# Counter: 0036
# Events left:  5790 Events right:  28489
# Events left:  11533 Events right:  22746
# Events left:  17404 Events right:  16875
# Events left:  23228 Events right:  11051
# Events left:  28803 Events right:  5476
# Counter: 0042
# Events left:  5607 Events right:  26338
# Events left:  10939 Events right:  21006
# Events left:  16309 Events right:  15636
# Events left:  21586 Events right:  10359
# Events left:  26760 Events right:  5185
# Counter: 0048
# Events left:  5066 Events right:  26813
# Events left:  10347 Events right:  21532
# Events left:  15462 Events right:  16417
# Events left:  20430 Events right:  11449
# Events left:  26128 Events right:  5751
# Counter: 0054
# Events left:  5782 Events right:  31598
# Events left:  12054 Events right:  25326
# Events left:  18686 Events right:  18694
# Events left:  25014 Events right:  12366
# Events left:  31148 Events right:  6232
# Counter: 0060
# Events left:  6369 Events right:  31824
# Events left:  12589 Events right:  25604
# Events left:  18742 Events right:  19451
# Events left:  25214 Events right:  12979
# Events left:  31616 Events right:  6577
# Counter: 0066
# Events left:  6573 Events right:  34470
# Events left:  13158 Events right:  27885
# Events left:  20103 Events right:  20940
# Events left:  26950 Events right:  14093
# Events left:  33803 Events right:  7240
# Counter: 0072
# Events left:  7302 Events right:  38905
# Events left:  14838 Events right:  31369
# Events left:  22427 Events right:  23780
# Events left:  30292 Events right:  15915
# Events left:  38159 Events right:  8048
# Counter: 0078
# Events left:  8348 Events right:  42862
# Events left:  16750 Events right:  34460
# Events left:  25144 Events right:  26066
# Events left:  33699 Events right:  17511
# Events left:  42488 Events right:  8722
# Counter: 0084
# Events left:  9155 Events right:  47252
# Events left:  18287 Events right:  38120
# Events left:  27597 Events right:  28810
# Events left:  37125 Events right:  19282
# Events left:  46737 Events right:  9670
# Counter: 0090
# Events left:  9771 Events right:  49642
# Events left:  19494 Events right:  39919
# Events left:  29258 Events right:  30155
# Events left:  39030 Events right:  20383
# Events left:  49129 Events right:  10284
# Counter: 0096
# Events left:  10422 Events right:  54613
# Events left:  21001 Events right:  44034
# Events left:  31897 Events right:  33138
# Events left:  42836 Events right:  22199
# Events left:  53989 Events right:  11046
# Counter: 0102
# Events left:  11163 Events right:  58752
# Events left:  22718 Events right:  47197
# Events left:  34274 Events right:  35641
# Events left:  46036 Events right:  23879
# Events left:  58094 Events right:  11821
# Counter: 0108
# Events left:  11956 Events right:  61746
# Events left:  24085 Events right:  49617
# Events left:  36264 Events right:  37438
# Events left:  48605 Events right:  25097
# Events left:  61019 Events right:  12683
# Counter: 0114
# Events left:  12725 Events right:  65593
# Events left:  25702 Events right:  52616
# Events left:  38557 Events right:  39761
# Events left:  51580 Events right:  26738
# Events left:  64780 Events right:  13538
# Counter: 0120
# Events left:  13453 Events right:  71853
# Events left:  27358 Events right:  57948
# Events left:  41460 Events right:  43846
# Events left:  55898 Events right:  29408
# Events left:  70453 Events right:  14853
# Counter: 0126
# Events left:  14873 Events right:  78219
# Events left:  29901 Events right:  63191
# Events left:  45179 Events right:  47913
# Events left:  60974 Events right:  32118
# Events left:  76946 Events right:  16146
# Counter: 0132
# Events left:  16229 Events right:  85321
# Events left:  32953 Events right:  68597
# Events left:  49526 Events right:  52024
# Events left:  66472 Events right:  35078
# Events left:  84015 Events right:  17535
# Counter: 0138
# Events left:  17647 Events right:  92345
# Events left:  35805 Events right:  74187
# Events left:  53797 Events right:  56195
# Events left:  72336 Events right:  37656
# Events left:  91276 Events right:  18716
# Counter: 0144
# Events left:  19327 Events right:  99782
# Events left:  38819 Events right:  80290
# Events left:  58663 Events right:  60446
# Events left:  78629 Events right:  40480
# Events left:  98621 Events right:  20488
# Counter: 0150
# Events left:  20574 Events right:  106290
# Events left:  41494 Events right:  85370
# Events left:  62515 Events right:  64349
# Events left:  83740 Events right:  43124
# Events left:  105119 Events right:  21745
# Counter: 0156
# Events left:  21968 Events right:  112074
# Events left:  44225 Events right:  89817
# Events left:  66361 Events right:  67681
# Events left:  88539 Events right:  45503
# Events left:  110979 Events right:  23063
# Counter: 0162
# Events left:  22932 Events right:  118205
# Events left:  46606 Events right:  94531
# Events left:  69696 Events right:  71441
# Events left:  93725 Events right:  47412
# Events left:  117047 Events right:  24090
# Counter: 0168
# Events left:  23913 Events right:  123431
# Events left:  48500 Events right:  98844
# Events left:  72875 Events right:  74469
# Events left:  97151 Events right:  50193
# Events left:  122187 Events right:  25157
# Counter: 0174
# Events left:  25466 Events right:  129814
# Events left:  51159 Events right:  104121
# Events left:  76888 Events right:  78392
# Events left:  102750 Events right:  52530
# Events left:  129609 Events right:  25671
# Counter: 0180
# Events left:  26818 Events right:  135033
# Events left:  53641 Events right:  108210
# Events left:  80294 Events right:  81557
# Events left:  107674 Events right:  54177
# Events left:  134986 Events right:  26865
# Counter: 0186
# Events left:  27414 Events right:  137689
# Events left:  54658 Events right:  110445
# Events left:  82085 Events right:  83018
# Events left:  109563 Events right:  55540
# Events left:  137554 Events right:  27549
# Counter: 0192
# Events left:  28382 Events right:  141365
# Events left:  56085 Events right:  113662
# Events left:  84596 Events right:  85151
# Events left:  112570 Events right:  57177
# Events left:  140993 Events right:  28754
# Counter: 0198
# Events left:  28198 Events right:  143410
# Events left:  56663 Events right:  114945
# Events left:  85443 Events right:  86165
# Events left:  113912 Events right:  57696
# Events left:  142708 Events right:  28900
# Counter: 0204
# Events left:  27915 Events right:  143023
# Events left:  56872 Events right:  114066
# Events left:  85223 Events right:  85715
# Events left:  113582 Events right:  57356
# Events left:  142246 Events right:  28692
# Counter: 0210
# Events left:  28651 Events right:  141297
# Events left:  57087 Events right:  112861
# Events left:  85680 Events right:  84268
# Events left:  113940 Events right:  56008
# Events left:  141678 Events right:  28270
# Counter: 0216
# Events left:  27405 Events right:  137971
# Events left:  55264 Events right:  110112
# Events left:  82880 Events right:  82496
# Events left:  110867 Events right:  54509
# Events left:  138235 Events right:  27141
# Counter: 0222
# Events left:  27776 Events right:  136095
# Events left:  55018 Events right:  108853
# Events left:  82773 Events right:  81098
# Events left:  109477 Events right:  54394
# Events left:  136748 Events right:  27123
# Counter: 0228
# Events left:  27460 Events right:  135674
# Events left:  54316 Events right:  108818
# Events left:  81514 Events right:  81620
# Events left:  108644 Events right:  54490
# Events left:  136094 Events right:  27040
# Counter: 0234
# Events left:  27072 Events right:  135008
# Events left:  54089 Events right:  107991
# Events left:  81143 Events right:  80937
# Events left:  108201 Events right:  53879
# Events left:  135168 Events right:  26912
# Counter: 0240
# Events left:  27320 Events right:  134906
# Events left:  54452 Events right:  107774
# Events left:  80948 Events right:  81278
# Events left:  107916 Events right:  54310
# Events left:  135013 Events right:  27213
# Counter: 0246
# Events left:  27065 Events right:  133527
# Events left:  53443 Events right:  107149
# Events left:  80826 Events right:  79766
# Events left:  107263 Events right:  53329
# Events left:  134291 Events right:  26301
# Counter: 0252
# Events left:  26788 Events right:  132209
# Events left:  53118 Events right:  105879
# Events left:  79945 Events right:  79052
# Events left:  106375 Events right:  52622
# Events left:  132559 Events right:  26438
# Counter: 0258
# Events left:  26180 Events right:  131470
# Events left:  52651 Events right:  104999
# Events left:  78855 Events right:  78795
# Events left:  104968 Events right:  52682
# Events left:  131471 Events right:  26179
# Counter: 0264
# Events left:  26259 Events right:  129685
# Events left:  52691 Events right:  103253
# Events left:  78210 Events right:  77734
# Events left:  104129 Events right:  51815
# Events left:  130011 Events right:  25933
# Counter: 0270
# Events left:  26098 Events right:  127233
# Events left:  51299 Events right:  102032
# Events left:  77088 Events right:  76243
# Events left:  102692 Events right:  50639
# Events left:  127941 Events right:  25390
# Counter: 0276
# Events left:  25229 Events right:  125094
# Events left:  50442 Events right:  99881
# Events left:  75459 Events right:  74864
# Events left:  100381 Events right:  49942
# Events left:  125347 Events right:  24976
# Counter: 0282
# Events left:  25039 Events right:  122559
# Events left:  49418 Events right:  98180
# Events left:  73849 Events right:  73749
# Events left:  98507 Events right:  49091
# Events left:  123185 Events right:  24413
# Counter: 0288
# Events left:  24562 Events right:  121710
# Events left:  49385 Events right:  96887
# Events left:  73479 Events right:  72793
# Events left:  97914 Events right:  48358
# Events left:  122060 Events right:  24212
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
# !ffmpeg -i "$FRAME_OUTPUT_DIR"/%06d.png timelens.mp4
from google.colab import files
files.download("timelens.mp4")
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '/content/rpg_timelens/output_frames/%06d.png':
#   Duration: 00:00:11.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 957x856, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d446029c40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d446029c40] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55d446029c40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'timelens.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 957x856, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  295 fps= 14 q=-1.0 Lsize=    2938kB time=00:00:11.68 bitrate=2060.8kbits/s speed=0.546x
# video:2934kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.145820%
# [libx264 @ 0x55d446029c40] frame I:2     Avg QP:20.45  size:178712
# [libx264 @ 0x55d446029c40] frame P:93    Avg QP:22.32  size: 21932
# [libx264 @ 0x55d446029c40] frame B:200   Avg QP:29.06  size:  3033
# [libx264 @ 0x55d446029c40] consecutive B-frames:  3.7% 15.6%  6.1% 74.6%
# [libx264 @ 0x55d446029c40] mb I  I16..4:  4.6% 71.3% 24.1%
# [libx264 @ 0x55d446029c40] mb P  I16..4:  0.1%  0.8%  0.3%  P16..4: 32.7% 14.4% 11.6%  0.0%  0.0%    skip:40.1%
# [libx264 @ 0x55d446029c40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 24.2%  2.8%  0.7%  direct: 1.4%  skip:70.8%  L0:32.9% L1:56.4% BI:10.6%
# [libx264 @ 0x55d446029c40] 8x8 transform intra:70.5% inter:56.7%
# [libx264 @ 0x55d446029c40] coded y,u,v intra: 85.4% 48.2% 43.9% inter: 12.3% 2.0% 1.7%
# [libx264 @ 0x55d446029c40] i16 v,h,dc,p: 25% 30% 21% 25%
# [libx264 @ 0x55d446029c40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 22% 19%  6%  8%  7%  8%  7% 11%
# [libx264 @ 0x55d446029c40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 20% 17%  7%  9%  7%  9%  7%  9%
# [libx264 @ 0x55d446029c40] Weighted P-Frames: Y:6.5% UV:2.2%
# [libx264 @ 0x55d446029c40] ref P L0: 53.3% 22.0% 18.5%  5.8%  0.4%
# [libx264 @ 0x55d446029c40] ref B L0: 91.0%  6.8%  2.2%
# [libx264 @ 0x55d446029c40] ref B L1: 94.3%  5.7%
# [libx264 @ 0x55d446029c40] kb/s:2036.41
